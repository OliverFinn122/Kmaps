# %%
# %run classes.ipynb
# %run functions.ipynb

import os.path
from opencage.geocoder import OpenCageGeocode
import folium
from folium import Tooltip
import pickle 
from typing import List
import ipywidgets as widgets
from ipywidgets import interact, interactive, fixed, interact_manual, IntSlider, Output
from IPython.display import clear_output, display
from datetime import datetime
import pytz
from typing import List
from copy import deepcopy
import random
from geopy.distance import geodesic
import numpy as np

#old_clients = load_old_clients('data.pickle')
#full_client_list = update_clients(old_clients)

full_client_list = load_clients_pickle('client_data.pickle')

days_of_week = {0: 'Sunday', 1: 'Monday', 2: 'Tuesday', 3: 'Wednesday', 4: 'Thursday', 5: 'Friday', 6: 'Saturday'}

out = Output()
out2 = Output()
out3 = Output()

time_slider = widgets.IntSlider(min=6, max=23, step=1)
print("time slider military time 6 - 23")
display(time_slider, out2)
time_slider.observe(hourly, names='value')

slider = widgets.IntSlider(min=0, max=6, step=1)
print("day slider")
display(slider, out)
slider.observe(weekly, names = 'value')

# Create separate sliders for day and time
day_slider = widgets.IntSlider(min=0, max=6, step=1, description='Day:')
time_slider_2 = widgets.IntSlider(min=6, max=23, step=1, description='Time:')

# Combine the two sliders into a single widget
day_and_time_slider = widgets.VBox([day_slider, time_slider_2])

# Set the observer for each slider
day_slider.observe(filter_by_day_and_time, names='value')
time_slider_2.observe(filter_by_day_and_time, names='value')

# Display the new widget
display(day_and_time_slider, out3)

sunday_map = filter_and_save(full_client_list, "Sunday")
monday_map = filter_and_save(full_client_list, "Monday")
tuesday_map = filter_and_save(full_client_list, "Tuesday")
wednesday_map = filter_and_save(full_client_list, "Wednesday")
thursday_map = filter_and_save(full_client_list, "Thursday")
friday_map = filter_and_save(full_client_list, "Friday")
saturday_map = filter_and_save(full_client_list, "Saturday")
        
time_client_list = modify_time(full_client_list)

#for client in time_client_list:
    #print(client)
    
#test change

while True: 
    inp = input("Enter add, delete, search, print, map, day, time, day-time, center, mobile or e to exit: ")
    if inp.lower() == 'add':
        add_client()
        remove_append()
    elif inp.lower() == 'delete':
        remove()
    elif inp.lower() == 'search':
        search()
    elif inp.lower() == 'print':
        for client in full_client_list:
            print(client)
    elif inp.lower() == 'map':
        map_nyc = create_map(full_client_list)
        display(map_nyc)
    elif inp.lower() == 'day':
        pass
        break
    elif inp.lower() == 'time':
        pass
        break
    elif inp.lower() == "day-time":
        pass
        break
    elif inp.lower() == 'e':
        break
    elif inp.lower() == 'mobile':
        Klist = location_filter(full_client_list, "Monday");
        Kmap = k_map_mobile(Klist)
        display(Kmap)
    elif inp.lower() == 'center':
        day = str(input("Enter day or all: "))
        if day.lower() == "all":
            Kmap = k_map(full_client_list)
            display(Kmap)
        if day.lower() == "sunday":
            Klist = location_filter(full_client_list, "Sunday");
            Kmap = k_map(Klist)
            display(Kmap)
        if day.lower() == "monday":
            Klist = location_filter(full_client_list, "Monday");
            Kmap = k_map(Klist)
            display(Kmap)
        if day.lower() == "tuesday":
            Klist = location_filter(full_client_list, "Tuesday");
            Kmap = k_map(Klist)
            display(Kmap)
        if day.lower() == "wednesday":
            Klist = location_filter(full_client_list, "Wednesday");
            Kmap = k_map(Klist)
            display(Kmap)
        if day.lower() == "thursday":
            Klist = location_filter(full_client_list, "Thursday");
            Kmap = k_map(Klist)
            display(Kmap)
        if day.lower() == "friday":
            Klist = location_filter(full_client_list, "Friday");
            Kmap = k_map(Klist)
            display(Kmap)
        if day.lower() == "saturday":
            Klist = location_filter(full_client_list, "Saturday");
            Kmap = k_map(Klist)
            display(Kmap) 
    else:
        print("Invalid input")
        
from IPython.display import HTML

HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
<form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>''')
# Out:
# time slider military time 6 - 23
# IntSlider(value=6, max=23, min=6)
# Output()
# day slider
# IntSlider(value=0, max=6)
# Output()
# VBox(children=(IntSlider(value=0, description='Day:', max=6), IntSlider(value=6, description='Time:', max=23, …
# Output()
# Enter add, delete, search, print, map, day, time, day-time, center, mobile or e to exit: mobile
# Enter the value of k: 2
# Assigned Locations: [(40.7570841, -73.9724543), (40.7804903, -73.9811314), (40.7623618, -73.9852044), (40.8011158, -73.9589707), (40.7601258, -73.9800192)]
# Distances: [2.700513224191, 0.0, 2.042316905284726, 2.957112329711015, 2.2634155212475835]
# Assigned Locations: [(40.7198779, -74.010019), (40.7202082, -74.0099615), (40.7179876, -74.013842), (40.7369702, -73.980291), (40.7190437, -74.0009112), (40.7210619, -74.008575), (40.7261454, -73.984022), (40.7100733, -74.0139564), (40.7401703, -73.9896112), (40.7369057, -73.9962778), (40.6962912, -73.9900433)]
# Distances: [0.7750820908593599, 0.7755236707580071, 1.0988269787134384, 2.645277487162294, 0.0, 0.6852046892911111, 1.6303480037413514, 1.4857108272963442, 2.532856534547029, 2.0218042521582356, 2.6883632024266437]
# [(40.7198779, -74.010019), (40.7202082, -74.0099615), (40.7179876, -74.013842), (40.7570841, -73.9724543), (40.7210619, -74.008575), (40.7261454, -73.984022), (40.7100733, -74.0139564), (40.6962912, -73.9900433)]
# Iteration 3:
# Center 1: (40.7570841, -73.9724543)
# Total Distance for Center 1: 0.0
# Distance for Location with Maximum Distance: 0.0
# Total Distance for Iteration 3: 0.0
# ========================
# Center 2: (40.7100733, -74.0139564)
# Total Distance for Center 2: 10.12524915444207
# Distance for Location with Maximum Distance: 3.0955581256313858
# Total Distance for Iteration 3: 10.12524915444207
# ========================
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_dff01fda67d9d28d9d7cc9f36cfecde5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_dff01fda67d9d28d9d7cc9f36cfecde5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_dff01fda67d9d28d9d7cc9f36cfecde5 = L.map(
#                 &quot;map_dff01fda67d9d28d9d7cc9f36cfecde5&quot;,
#                 {
#                     center: [40.7128, -74.006],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b2f2389714d18bca911b4fefe9e09b34 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_dff01fda67d9d28d9d7cc9f36cfecde5);
#
#
#             var marker_4392ae1aa5f3df62447ee5f5323e85a7 = L.marker(
#                 [40.7570841, -73.9724543],
#                 {}
#             ).addTo(map_dff01fda67d9d28d9d7cc9f36cfecde5);
#
#
#             var icon_b74a9daeb06da4a350d1af3eb5750a62 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;orange&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_4392ae1aa5f3df62447ee5f5323e85a7.setIcon(icon_b74a9daeb06da4a350d1af3eb5750a62);
#
#
#             var marker_1faf43a635b8f0d11bfe1a50ddd67c58 = L.marker(
#                 [40.7570841, -73.9724543],
#                 {}
#             ).addTo(map_dff01fda67d9d28d9d7cc9f36cfecde5);
#
#
#             var icon_bbbf4140447c8474b208c74dfae24bd4 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_1faf43a635b8f0d11bfe1a50ddd67c58.setIcon(icon_bbbf4140447c8474b208c74dfae24bd4);
#
#
#             var marker_527d9eef5d479015487b8c2e6727df2d = L.marker(
#                 [40.7198779, -74.010019],
#                 {}
#             ).addTo(map_dff01fda67d9d28d9d7cc9f36cfecde5);
#
#
#             var icon_5e3a050732e13062f14e4d9d13cb3212 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_527d9eef5d479015487b8c2e6727df2d.setIcon(icon_5e3a050732e13062f14e4d9d13cb3212);
#
#
#             var marker_be0ec9282f8f09df20368f59dc9f2327 = L.marker(
#                 [40.7202082, -74.0099615],
#                 {}
#             ).addTo(map_dff01fda67d9d28d9d7cc9f36cfecde5);
#
#
#             var icon_29e0120faf45401ecfe09665c3f3b31b = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_be0ec9282f8f09df20368f59dc9f2327.setIcon(icon_29e0120faf45401ecfe09665c3f3b31b);
#
#
#             var marker_2ef3fa5448cd09639b27232604906484 = L.marker(
#                 [40.7179876, -74.013842],
#                 {}
#             ).addTo(map_dff01fda67d9d28d9d7cc9f36cfecde5);
#
#
#             var icon_2218f7072d0bacae5b2eddf201c56734 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_2ef3fa5448cd09639b27232604906484.setIcon(icon_2218f7072d0bacae5b2eddf201c56734);
#
#
#             var marker_57bfb204a506b3d33fb780447fb977df = L.marker(
#                 [40.7210619, -74.008575],
#                 {}
#             ).addTo(map_dff01fda67d9d28d9d7cc9f36cfecde5);
#
#
#             var icon_2edd355143015776246eb55da7a0c8e7 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_57bfb204a506b3d33fb780447fb977df.setIcon(icon_2edd355143015776246eb55da7a0c8e7);
#
#
#             var marker_969dd4b1408da42de6f1cfc8a0bb3b4c = L.marker(
#                 [40.7261454, -73.984022],
#                 {}
#             ).addTo(map_dff01fda67d9d28d9d7cc9f36cfecde5);
#
#
#             var icon_d64e497d08f05351290b2acf829f92c8 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot
# Optimal Centers: [(40.7570841, -73.9724543), (40.7100733, -74.0139564)]
# Optimal Centers: [(40.7804903, -73.9811314), (40.7190437, -74.0009112)]
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_49bf2d15ddceab1b56c6e8581dd4aad9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_49bf2d15ddceab1b56c6e8581dd4aad9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_49bf2d15ddceab1b56c6e8581dd4aad9 = L.map(
#                 &quot;map_49bf2d15ddceab1b56c6e8581dd4aad9&quot;,
#                 {
#                     center: [40.7128, -74.006],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_eab4e33a621fd787463e0afb971d9026 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_49bf2d15ddceab1b56c6e8581dd4aad9);
#
#
#             var marker_fcde45b2ff4e90127d301ce79c5e477b = L.marker(
#                 [40.7198779, -74.010019],
#                 {}
#             ).addTo(map_49bf2d15ddceab1b56c6e8581dd4aad9);
#
#
#         var popup_ede6591ce46b8c919d7f0164afe48aaf = L.popup({&quot;maxWidth&quot;: 250});
#
#
#
#                 var html_b383fbebaed3f6152202bcef1e08ab28 = $(`&lt;div id=&quot;html_b383fbebaed3f6152202bcef1e08ab28&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;strong&gt;Name:&lt;/strong&gt; Luann&lt;br&gt;&lt;strong&gt;Time:&lt;/strong&gt; [&#x27;Monday 6/5 10:05am&#x27;]&lt;br&gt;&lt;strong&gt;Length:&lt;/strong&gt; 20 minutes&lt;br&gt;&lt;strong&gt;Address:&lt;/strong&gt; 377 Greenwich St, New York, NY 10013&lt;/div&gt;`)[0];
#                 popup_ede6591ce46b8c919d7f0164afe48aaf.setContent(html_b383fbebaed3f6152202bcef1e08ab28);
#
#
#
#         marker_fcde45b2ff4e90127d301ce79c5e477b.bindPopup(popup_ede6591ce46b8c919d7f0164afe48aaf)
#         ;
#
#
#
#
#             marker_fcde45b2ff4e90127d301ce79c5e477b.bindTooltip(
#                 `&lt;div&gt;
#                      Luann
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_c42792f318d254f03574fd1e9bd7bd8a = L.marker(
#                 [40.7202082, -74.0099615],
#                 {}
#             ).addTo(map_49bf2d15ddceab1b56c6e8581dd4aad9);
#
#
#         var popup_bfe33f01655a14cc921d7497c3994ff8 = L.popup({&quot;maxWidth&quot;: 250});
#
#
#
#                 var html_af1330e6748bc8c4366ec2f772bb11d7 = $(`&lt;div id=&quot;html_af1330e6748bc8c4366ec2f772bb11d7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;strong&gt;Name:&lt;/strong&gt; Jeter&amp;Andy&lt;br&gt;&lt;strong&gt;Time:&lt;/strong&gt; [&#x27;Monday 6/5 8:30pm&#x27;]&lt;br&gt;&lt;strong&gt;Length:&lt;/strong&gt; 30 minutes&lt;br&gt;&lt;strong&gt;Address:&lt;/strong&gt; 385 Greenwich St, New York, NY 10013&lt;/div&gt;`)[0];
#                 popup_bfe33f01655a14cc921d7497c3994ff8.setContent(html_af1330e6748bc8c4366ec2f772bb11d7);
#
#
#
#         marker_c42792f318d254f03574fd1e9bd7bd8a.bindPopup(popup_bfe33f01655a14cc921d7497c3994ff8)
#         ;
#
#
#
#
#             marker_c42792f318d254f03574fd1e9bd7bd8a.bindTooltip(
#                 `&lt;div&gt;
#                      Jeter&amp;Andy
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_82585b054aedd17f755bb19e42da34a6 = L.marker(
#                 [40.7179876, -74.013842],
#                 {}
#             ).addTo(map_49bf2d15ddceab1b56c6e8581dd4aad9);
#
#
#         var popup_2523bc1b3d6fcf222a2ae70a87515ca3 = L.popup({&quot;maxWidth&quot;: 250});
#
#
#
#                 var html_262827379b2e916e1916a1086e1f5ce0 = $(`&lt;div id=&quot;html_262827379b2e916e1916a1086e1f5ce0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;strong&gt;Name:&lt;/strong&gt; Rocco&lt;br&gt;&lt;strong&gt;Time:&lt;/strong&gt; [&#x27;Sunday 6/4 6:40pm&#x27;, &#x27;Monday 6/5 10:10pm&#x27;]&lt;br&gt;&lt;strong&gt;Length:&lt;/strong&gt; 60 minutes&lt;br&gt;&lt;strong&gt;Address:&lt;/strong&gt; 345 Chambers St, New York, NY 10282&lt;/div&gt;`)[0];
#                 popup_2523bc1b3d6fcf222a2ae70a87515ca3.setContent(html_262827379b2e916e1916a1086e1f5ce0);
#
#
#
#         marker_82585b054aedd17f755bb19e42da34a6.bindPopup(popup_2523bc1b3d6fcf222a2ae70a87515ca3)
#         ;
#
#
#
#
#             marker_82585b054aedd17f755bb19e42da34a6.bindTooltip(
#                 `&lt;div&gt;
#                      Rocco
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_d55b96344991deb827f5929fc199ddd8 = L.marker(
#                 [40.7570841, -73.9724543],
#                 {}
#             ).addTo(map_49bf2d15ddceab1b56c6e8581dd4aad9);
#
#
#         var popup_1453141e9e35f67adfed5b686abc3073 = L.popup({&quot;maxWidth&quot;: 250});
#
#
#
#                 var html_678d5c3efcbb1464b06066b3264ad311 = $(`&lt;div id=&quot;html_678d5c3efcbb1464b06066b3264ad311&quot; style=&quot;width: 100.0%; height: 100.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 72
#      66 #for client in time_client_list:
#      67     #print(client)
#      68
#      69 #test change
#      71 while True:
# ---> 72     inp = input("Enter add, delete, search, print, map, day, time, day-time, center, mobile or e to exit: ")
#      73     if inp.lower() == 'add':
#      74         add_client()
#
# File /opt/homebrew/lib/python3.11/site-packages/ipykernel/kernelbase.py:1182, in Kernel.raw_input(self, prompt)
#    1180     msg = "raw_input was called, but this frontend does not support input requests."
#    1181     raise StdinNotImplementedError(msg)
# -> 1182 return self._input_request(
#    1183     str(prompt),
#    1184     self._parent_ident["shell"],
#    1185     self.get_parent("shell"),
#    1186     password=False,
#    1187 )
#
# File /opt/homebrew/lib/python3.11/site-packages/ipykernel/kernelbase.py:1225, in Kernel._input_request(self, prompt, ident, parent, password)
#    1222 except KeyboardInterrupt:
#    1223     # re-raise KeyboardInterrupt, to truncate traceback
#    1224     msg = "Interrupted by user"
# -> 1225     raise KeyboardInterrupt(msg) from None
#    1226 except Exception:
#    1227     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
